# %% [markdown]
# # Report

# %% [markdown]
# # **1. Introduction**
#
# The US cell phone service market is incredibly saturated and most adults already have a provider. Because of this, telecom companies can't rely on steady new customer growth and instead depend heavily on customer retention. Losing a customer means losing all future monthly revenue and often paying additional costs to acquire a replacement. That makes the ability of being able to identify customers who are likely to leave strategically important for profits, scale, and efficency.
#
# This project analyzes the IBM Telco Customer Churn dataset which simulates a telecom company’s customer base. Each row describes one customer and includes demographic information, services used, billing details, and whether the customer left in the past month. The goal of this work is to identify patterns associated with customer churn and to evaluate two predictive models (logistic regression and a pruned decision tree) to see how well they predict high-risk customers. The analysis is exploratory and aims to highlight insights that could guide real-world retention strategies.

# %% [markdown]
# # **2. Background and Motivation**
#
# Telecom companies face intense competition and limited opportunities for expansion through new customer acquisition. Retaining existing customers is generally more cost-effective than recruiting new ones. Predictive churn modeling provides a way to flag high-risk customers early, allowing companies to offer targeted support or incentives.
#
# This project focuses on three main questions:
#
# 1. Are newer customers (shorter tenure) more likely to churn?
# 2. How do pricing and contract structure relate to churn risk?
# 3. How well do two simple models of logistic regression and a pruned decision tree distinguish churners from non-churners?
#
# The dataset includes demographic attributes, subscribed services, contract type, billing information, and whether the customer churned in the past month. Approximately three-quarters of customers do not churn, producing a clear class imbalance that affects model evaluation. Because accuracy can be misleading in this context, we rely on AUC (Area Under the ROC Curve) as a complementary metric.
#
# These variables allow us to explore how customer characteristics relate to churn and whether simple supervised learning models can predict churn reliably enough to assist with retention strategies.
#
#
# Churn is the rate at which customers leave a company over a given time period.
# Churn rate = (Number of customers who leave during a period) ÷ (Total customers at the start of the period)
# A company has high churn risk if they are likely to leave the company soon. A customer is low churn risk if they are unlikely to leave the company soon
# In this dataset, churn is recorded as either “Yes” for customers who left in the past month or “No” for those who stayed. About three-quarters of the customers do not churn, which creates an imbalance that makes prediction more difficult. Any model must do more than simply predict “No” for every customer.
#
# The dataset includes several types of variables:
# Dataset:
# Fictional dataset produced by ibm of a fictional company called Telco.
# Content
# Each row represents a customer, each column contains customer attributes described on the column Metadata.
# The data set includes information about:
# Customers who left within the last month (the column is called Churn)
# Services that each customer has signed up for (phone, multiple lines, internet, online security, online backup, device protection, tech support, and streaming TV and movies)
# Customer account information (how long they’ve been a customer, contract, payment method, paperless billing, monthly charges, and total charges)
# Demographic info about customers (gender, age range, and if they have partners and dependents)
#
# To explore this type of models and learn more about the subject.
# Columns
# Demographic information such as gender and senior citizen status
#  Service information such as phone plans, internet type, and streaming services
#  Account information such as tenure, contract type, monthly charges, and payment method
#  Cumulative billing totals through the TotalCharges variable
# These features allow us to explore questions such as whether new customers are more likely to leave, whether higher monthly bills relate to churn, and whether contract length influences customer loyalty. We assume the churn labels are accurate, services are correctly recorded, and no measurement bias exists in billing or tenure fields.

# %% [markdown]
# # **3. Exploratory Data Analysis and Key Observations**
#
# Before modeling, we examined the distributions and relationships among the variables. Below are the key visualizations used to find and understand churn patterns.
#
# ## **Figure 1. Churn Distribution**
#
# ![Churn Distribution](Output/Churn_dist_bar.png)
#
# **Caption:**
# Figure 1 shows that around ~75% of customers do not churn. This imbalance makes accuracy alone an inadequate performance metric, motivating the use of AUC.
#
# ## **Figure 2. Distribution of Customer Tenure**
#
# ![Customer Tenure](Output/Dist_customer_tenure.png)
#
# **Caption:**
# Figure 2 shows the distribution of tenure. Many customers are either very new or near the maximum tenure of 72 months, suggesting two distinct groups in the customer base (New and Long Standing Customer).
#
# ## **Figure 3. Distribution of Monthly Charges**
#
# ![Monthly Charges](Output/Dist_monthly_charges.png)
#
# **Caption:**
# Figure 3 shows large variation in monthly charges, showing differences in service bundles and pricing plans across customers.
#
# ## **Figure 4. Contract Type Distribution**
#
# ![Contract Type Distribution](Output/Dist_contract_type.png)
#
# **Caption:**
# Figure 4 illustrates that most customers are on month-to-month contracts which often provide less commitment and greater likelihood of churn.
#
# ## **Figure 5. Churn Rate by Contract Type**
#
# ![Churn by Contract](Output/Churn_by_contract.png)
#
# **Caption:**
# Figure 5 shows that churn rates are dramatically higher among month-to-month customers (matching reasoning), while one-year and two-year contract customers churn far less frequently. Contract type appears to be one of the strongest predictors of churn.

# %% [markdown]
# # **4. Modeling Approach**
#
# Two predictive models were used in this analysis: logistic regression and a decision tree classifier. These models are transparent, easy to interpret, and consistent with the exploratory goals of the project.
#
# ### **Logistic Regression**
# Trained on all columns except customerID and Churn. We use this model to predict churn. Logistic regression provides a simple baseline and outputs estimated probabilities of churn. All predictor variables were included except customerID and the churn label. Categorical variables were converted into indicator variables. Logistic regression performs well on many churn datasets and offers insight into how each variable affects churn risk. We split the data into a training set and a 20 percent held-out test set using stratified sampling to preserve the churn proportion. Logistic regression was fit on the training data, with all categorical features encoded as indicator variables. We evaluated the model using test accuracy and the area under the ROC curve (AUC), because accuracy alone can be misleading with imbalanced outcomes.
#
# ### **Decision Tree**
# Trained on all columns except customer ID and Churn. I decided to leave all hyperparameters at their default and only tune ccp alpha.  I perform 5-fold Cross Validation using the accuracy scoring metric. I explored and visualized the ccp_alpha space by plugging in different ranges for ccp_alpha. I also experimented with different levels of ccp_alpha coarseness by varying the spacing between adjacent ccp_alpha values. All of this was done iteratively using np.linspace. After looking at the visualizations, I noticed a common shape in the plot: an increase in CV accuracy, followed by a flatline, followed by a decrease. I then zoomed in on the region where CV accuracy appeared to be largest. After looking at several plots, I eventually settled with a range of ccp_alpha from 0 to 0.035 and a coarseness of 100 evenly spaced values, as I determined it would be sufficient to capture the optimal ccp_alpha. The optimal ccp_alpha ended up being 0.0032. The accuracy of the CART model on the test set is 0.7818. Decision trees offer a more flexible approach. They can handle nonlinear interactions without manually constructing interaction terms. However, decision trees can overfit, so the model was pruned using cost complexity pruning. A grid of 100 values for the pruning parameter, ccp_alpha, ranging from 0 to 0.035, was evaluated using 5-fold cross validation. The pattern of results was clear: accuracy rose quickly from zero, stayed flat for a wide range of ccp_alpha values, and then declined when pruning became too aggressive. The best value was ccp_alpha = 0.0032. For the decision tree we used cost-complexity pruning. We performed 5-fold cross-validation over a grid of candidate ccp_alpha values between 0 and 0.035, using accuracy as the scoring metric. Cross-validated accuracy increased from very small ccp_alpha values, stayed flat over a broad middle region, and then declined once the tree was over-pruned. The best value, ccp_alpha = 0.0032, defines the pruned tree we evaluate on the test set.
#
# The AUC (Area Under the Curve) of both models, which measures how well the two models discriminate, were computed. The logistic regression model outperformed the tree model on both AUC and accuracy. Accuracy measures the overall fraction of correctly classified customers, while AUC measures how well the model ranks churners above non-churners across all probability thresholds. With an imbalanced outcome like churn, AUC is an important complement to accuracy.
#
# ## **Figure 6. Cross-Validation Accuracy vs ccp_alpha**
#
# ![Cross Validation](Output/Cross_validation_vs_ccp.png)
#
# **Caption:**
# Figure 6 shows cross-validated accuracy for various pruning strengths. Accuracy increases from very low complexity, stabilizes across a broad plateau, and declines once the tree is over-pruned. The selected value is ccp_alpha = 0.0032.

# %% [markdown]
# # **5. Results**
#
# Logistic regression achieved a test accuracy of about 0.7967 and an AUC of about 0.8305. The confusion matrix shows that logistic regression correctly identifies many non-churners while also catching a meaningful portion of churners (see figure 3), although some churners are still missed.
# The decision tree achieved a test accuracy of about 0.7818 and an AUC of about 0.7937. It correctly classifies many non-churners and produces fewer false positives than logistic regression, but it misses more true churners. This makes the tree more conservative. While its accuracy is only slightly lower than that of logistic regression, its lower AUC and higher number of missed churners reduce its usefulness for retention strategies.
# Overall, logistic regression performs better on this dataset. It is more balanced across the two classes and identifies more churners, which is often the most important outcome for a business seeking to prevent customer loss.

# %% [markdown]
# ## **Figure 7. Confusion Matrix for Logistic Regression**
#
# ![Logistic Confusion Matrix](Output/Confusion_matrix_logistic_regression.png)
#
# **Caption:**
# Figure 7 shows that logistic regression correctly classifies most non-churners and captures a meaningful proportion of churners, though some are missed.

# %% [markdown]
# ## **Figure 8. Confusion Matrix for Decision Tree**
#
# ![Tree Confusion Matrix](Output/Confusion_matrix_classification_tree.png)
#
# **Caption:**
# Figure 8 shows that the pruned classification tree produces fewer false positives but misses more true churners, making it less useful for retention targeting despite similar accuracy.

# %% [markdown]
# # **6. Interpretation and Implications**
#
# Insights from EDA/predictive modeling:
#
# Customers with short tenure are way more likely to leave, which has an implication that the early months of the relationship are especially fragile/the most important to foster and may benefit from focused onboarding and support. This is the time when customers don't have brand loyalty and need good impressions to decrease churmn. Customers with higher monthly charges also churn at higher rates, pointing toward the importance of perceived value. High bills without matching perceived benefits can push people away. Contract type is one of the strongest predictors, month-to-month customers churn far more often than those on one-year or two-year contracts, which lines up with the idea that commitment mechanisms and incentives to stay reduce the likelihood of leaving (locked into a contract with only a few, sparse oppurtunities to leave versus having the choice every single month). Finally, service bundles that add streaming, security, or technical support appear to be associated with lower churn in several of our summaries, which is consistent with the notion that deeper integration into the company’s ecosystem or higher percieved value of services makes it harder or less attractive to switch providers.
#
# If a real telecom company observed patterns like these in its own data:
#
# Extra attention could be directed toward customers in their first year through stronger onboarding and early  support. This could include things such as clearer explanations of billing and plan features at signup, proactive follow-up emails or messages in the first few months, dedicated customer support queues/priorities for new customers, or small welcome incentives such as temporary discounts, free add-ons, or data boosts. Usage monitoring during the first year could help identify early warning signs such as repeated service issues, unusually low engagement, or frequent customer service contacts, triggering outreach before dissatisfaction escalates. Training customer service representatives to prioritize retention during early interactions, rather than purely issue resolution, may also help stabilize customers before loyalty is established.
#
# Customers with unusually high monthly charges could be flagged for closer review, companies might use internal thresholds or percentile cutoffs to identify customers (through more modeling) with above average charges and then check whether their plans align with actual usage. Interventions could include plan optimization recommendations, clearer communication about what customers are paying for, loyalty discounts, or targeted promotions that reduce bill shock without broadly lowering prices. High charge customers could also be routed to more experienced support staff or offered service guarantees, faster issue resolution, or priority customer service to reinforce value perception. Internally, sales and support teams could be trained to avoid overselling plans that customers do not fully use, which may reduce downstream churn driven by dissatisfaction (less money initally but more money in the long run).
#
# Since month-to-month customers churn far more often, companies could encourage longer commitments by offering incentives such as reduced monthly rates, waived fees, device upgrades, or bundled add-ons for customers who voluntarily move to 1 year or 2 year contracts. Sales representatives could be trained to emphasize the long term cost savings and stability of longer contracts. Companies might also time contract offers strategically, such as after successful service interactions or once customers pass the high risk early tenure period, when customers may be more open to committing. Firms could design bundles that are easy to understand, transparently priced, and clearly valuable rather than having a sneaky business practice of hidden feeds (which may increase revenue but decrease brand perception). Bundles could be customized based on customer profiles, usage patterns, or household characteristics, making them feel more relevant and less like generic add-ons. None of these proposals guarantee any reduced churn, and none should be interpreted as causal prescriptions but all seem like reasonable suggestions given the patterns found in the dataset.

# %% [markdown]
# # **7. Assumptions and Limitations**
#
# ### **7.1 Assumptions**
# - Each row corresponds to a unique customer account.
# - Churn labels accurately reflect customer departures.
# - Tenure, charges, contract type, and service features are measured reliably.
# - Dropping rows with missing TotalCharges does not introduce systematic bias.
# - The snapshot is representative of customer behavior during the period analyzed.
#
# ### **7.2 Limitations**
# - This is observational data (no causal claims can be made).
# - The dataset is imbalanced, making accuracy insufficient without AUC.
# - Real telecom markets shift rapidly, so models must be re-trained regularly.
# - Only two simple models were used in this project so, more complex models could improve prediction % but reduce interpretability, reproducibility, and increase complexity.

# %% [markdown]
# # **8. Reproducibility and Workflow**
#
# To support reproducibility, utility functions such as compute_accuracy and compute_auc were placed in a separate module (utils.py) with accompanying docstrings and tests. These functions were imported into the analysis notebook to enforce modularity.
#
# The repository also includes:
#
# - environment.yml with all the code
# - Makefile automating environment setup and notebook execution
# - Saved figures in the output/directory
# - Notebook PDFs generated using MyST
# - Bibtex file

# %% [markdown]
# # **9. Conclusions**
#
# This project shows that simple predictive models can extract meaningful structure from the Telco churn dataset. Logistic regression performs slightly better than the decision tree in both accuracy and the ability to distinguish churners from non-churners. The exploratory analysis highlights the importance of tenure, contract type, and monthly charges. These patterns align with common business practices in the telecom industry. Even though the dataset is simulated and the analysis is exploratory, the results offer insight into effective retention strategies. In a saturated market, being able to identify high-risk customers can provide a significant market advantage.

# %% [markdown]
# # **10. Bibliography**

# %% [markdown]
# # **Author Contributions**
#
# - Marcel Gunadi: Conducted all the exploratory data analysis and built and assessed both models, utils.py
# - Benson Chang: utils functions docstring, Main Writeup, README, references file and output figures
# - Ethan Chant: Created inital files (repo, website, notebooks), README, Main Writeup, repo orginization, License
# - Sophie Hanson: Created myst website, pdf exports, binder badge, environment.yml, Makefile
